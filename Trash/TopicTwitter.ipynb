# %%
import gensim
from gensim.models import LdaModel
from gensim.corpora import Dictionary
from collections import Counter
import pandas as pd

# %%
# Ejemplos de tweets ya que no se cuenta la api
tweets = [
    "I love this new movie, it's so exciting!",
    "Just had a delicious dinner at my favorite restaurant.",
    "The traffic is terrible today, it took me hours to get home.",
    "Excited to attend the conference next week.",
    "Can't wait for the weekend getaway!",
    "This book is a must-read, highly recommended.",
    "The weather is perfect for a beach day.",
    "New album release from my favorite artist, loving the songs.",
    "Working hard on my project, making progress.",
    "Enjoying a cup of coffee and reading the news.",
    "Heading to the gym for a workout session.",
    "Attending a music concert tonight, super excited!",
    "Just finished a great workout, feeling energized.",
    "Trying out a new recipe, fingers crossed it turns out well.",
    "Planning a road trip with friends, can't wait to hit the road.",
    "Watching my favorite TV series, the suspense is killing me.",
    "Working late tonight to meet the deadline.",
    "Relaxing at home and listening to music.",
    "Exploring a new hiking trail, enjoying the nature.",
    "Celebrating my birthday with family and friends.",
    "Just booked tickets for my favorite band's concert!",
    "Eating pizza with friends, having a great time.",
    "Stuck in a long queue at the airport, it's frustrating.",
    "Excited for the new season of my favorite TV show.",
    "Attending a workshop on machine learning.",
    "Chilling at the beach, enjoying the sun and sand.",
    "Trying out a new yoga class, feeling relaxed.",
    "Watching a thrilling soccer match, go team!",
    "Busy day at work, lots of meetings and deadlines.",
    "Exploring a new city, loving the architecture.",
    "Sipping coffee and reading a good book.",
    "Hiking in the mountains, breathtaking views.",
    "Preparing for a job interview, fingers crossed.",
    "Relaxing at home, binge-watching a new series.",
    "Just adopted a cute puppy, so adorable!",
    "Enjoying a family picnic in the park.",
    "Attending a photography exhibition, beautiful captures.",
    "Late-night gaming session with friends.",
    "Trying a new recipe for dinner, fingers crossed.",
    "Road trip with friends, making unforgettable memories.",
    "Feeling inspired after attending a TEDx event.",
    "Can't wait for the weekend to unwind and relax.",
    "Productive day at work, accomplishing tasks.",
    "Exploring a new museum, learning fascinating things.",
    "Celebrating a milestone, feeling grateful.",
    "Relaxing with a cup of tea and a good movie.",
    "Preparing for a marathon, pushing my limits.",
    "Enjoying live music at a local pub.",
    "Just started learning a new language, exciting!",
    "Feeling motivated after a productive workout.",
    "Indulging in a spa day, pampering myself.",
    "Attending a fashion show, admiring the designs.",
    "Volunteering at a local charity, making a difference.",
    "Trying out a new hairstyle, feeling stylish.",
    "Baking cookies with my family, creating sweet memories.",
    "Enjoying a scenic bike ride, refreshing and invigorating.",
    "Celebrating a friend's wedding, love is in the air.",
    "Just got tickets for an upcoming music festival!",
    "Feeling grateful for the simple pleasures in life.",
    "Enjoying a leisurely Sunday brunch with loved ones.",
    "Feeling nostalgic while looking at old photographs.",
    "Excited for the launch of a new video game.",
    "Road trip to the countryside, embracing nature's beauty.",
    "Attending a theater performance, captivating and inspiring.",
    "Celebrating a friend's birthday, lots of fun and laughter.",
    "Enjoying a peaceful evening by the fireplace.",
    "Feeling inspired by a thought-provoking documentary.",
    "Trying out a new workout routine, challenging but rewarding.",
    "Exploring a new art exhibition, appreciating creativity.",
    "Attending a workshop on personal development.",
    "Feeling refreshed after a weekend getaway.",
    "Cooking a special dinner for a loved one.",
    "Enjoying a live stand-up comedy show, laughter therapy.",
    "Feeling proud after completing a DIY project.",
    "Attending a science conference, expanding knowledge.",
    "Indulging in some retail therapy, treating myself.",
    "Admiring the beauty of a sunset, nature's masterpiece.",
    "Excited for the release of a highly anticipated movie.",
    "Just finished a challenging workout at the gym.",
    "Excited for the upcoming football match tonight.",
    "Trying out a new recipe for a healthy salad.",
    "Attending a music concert with my friends.",
    "Feeling inspired after reading a motivational book.",
    "Enjoying a relaxing spa day, pampering myself.",
    "Exploring a new hiking trail, surrounded by nature's beauty.",
    "Celebrating a special occasion with my loved ones.",
    "Attending a technology conference, learning about the latest innovations.",
    "Feeling nostalgic while listening to old songs.",
    "Watching a thrilling suspense movie, on the edge of my seat.",
    "Indulging in some retail therapy, shopping for new clothes.",
    "Preparing for an important presentation at work.",
    "Enjoying a delicious meal at a new restaurant.",
    "Feeling excited about the upcoming vacation.",
    "Attending a yoga retreat for a weekend of relaxation.",
    "Trying out a new art technique, expressing my creativity.",
    "Relaxing at home, binge-watching a popular TV series.",
    "Feeling grateful for the support of my friends and family.",
    "Attending a business networking event, expanding my connections.",
    "Enjoying a bike ride in the park, embracing nature.",
    "Feeling motivated after attending a personal development seminar.",
    "Trying a new sport for the first time, challenging but fun.",
    "Exploring a new city, immersing myself in the culture.",
    "Attending a charity fundraiser, contributing to a good cause.",
    "Feeling proud after accomplishing a personal goal.",
    "Enjoying a picnic in the countryside, surrounded by greenery.",
    "Feeling inspired by a thought-provoking documentary.",
    "Excited for the weekend! Going to a beach party with friends.",
    "Just finished reading an amazing book, highly recommend it!",
    "Attending a conference on artificial intelligence, learning so much.",
    "Feeling motivated after a productive workout at the gym.",
    "Watching the latest episode of my favorite TV series, so intense!",
    "Trying out a new recipe for dinner, hoping it turns out delicious.",
    "Exploring a new hiking trail, enjoying the beautiful scenery.",
    "Celebrating my graduation with family and friends.",
    "Just bought tickets for a music concert, can't wait to see my favorite band.",
    "Having a movie night with popcorn and cozy blankets.",
    "Working on a new painting, expressing my creativity.",
    "Excited about the new technology gadgets launched today.",
    "Enjoying a cup of coffee and catching up on the latest news.",
    "Attending a workshop on photography, improving my skills.",
    "Feeling grateful for the support of my loved ones.",
    "Trying a new workout class, it's challenging but fun.",
    "Exploring a new city during my vacation, loving the architecture.",
    "Having a picnic in the park with friends, enjoying the sunshine.",
    "Just started a new job, looking forward to new opportunities.",
    "Watching a live sports match, cheering for my favorite team.",
    "Celebrating a special anniversary with my partner, love is in the air."
]


tweets_df = tweets1['tweet']

# %%
df = pd.read_csv('csv\carlos_hernandez_tweets.csv')

# Extraer la columna 'tweet' y convertirla en una lista
df = df['tweet'].tolist()

# Formatear los tweets de la manera que has mostrado
result = '\n'.join(f'"{tweet}"' for tweet in df)

print('tweets = [\n' + result + '\n]')
# Out:
# tweets = [
# "Qué emoción al ver cómo la tecnología 5G revoluciona la forma en que interactuamos con el mundo. ¡El futuro es ahora!"
# "Los algoritmos de recomendación de algunos servicios de streaming podrían mejorar mucho. ¡Es como si no me conocieran!"
# "Actualizando mi PC. Nada más emocionante que darle un poco de vida nueva a una vieja máquina."
# "La obsolescencia programada es una práctica que debe terminarse. Todos deberíamos poder usar nuestros dispositivos por más tiempo."
# "Aprendiendo más sobre inteligencia artificial. Impresionante cómo las máquinas pueden aprender y adaptarse."
# "A veces es desalentador ver cuánta desinformación hay sobre la ciberseguridad."
# "La realidad virtual no deja de asombrarme. Las posibilidades son infinitas."
# "Es triste ver cómo algunas compañías de tecnología no toman en serio la privacidad del usuario."
# "Probando el nuevo smartphone. A ver si cumple con las expectativas."
# ...

# %%
# Preprocesamiento de los tweets
preprocessed_tweets = [tweet.lower().split() for tweet in result]

# %%
# Creación del diccionario de palabras
dictionary = Dictionary(preprocessed_tweets)

# %%
# Creación del corpus de documentos
corpus = [dictionary.doc2bow(tweet) for tweet in preprocessed_tweets]

# %%
# Entrenamiento del modelo LDA
num_topics = 30
lda_model = LdaModel(corpus, num_topics=num_topics, id2word=dictionary, passes=200)

# %%
# Asignación de nombres a los tópicos
topic_names = {
    0: "News and Current Events" or "Noticias y eventos actuales" or "Actualités et événements en cours" or "Nachrichten und aktuelle Ereignisse" or "Notizie e eventi attuali",
    1: "Sports" or "Deportes" or "Sports" or "Sport" or "Sport",
    2: "Entertainment" or "Entretenimiento" or "Divertissement" or "Unterhaltung" or "Intrattenimento",
    3: "Politics" or "Política" or "Politique" or "Politik" or "Politica",
    4: "Technology" or "Tecnología" or "Technologie" or "Technologie" or "Tecnologia",
    5: "Fashion and Beauty" or "Moda y belleza" or "Mode et beauté" or "Mode und Schönheit" or "Moda e bellezza",
    6: "Travel" or "Viajes" or "Voyage" or "Reisen" or "Viaggi",
    7: "Health and Fitness" or "Salud y bienestar" or "Santé et forme physique" or "Gesundheit und Fitness" or "Salute e fitness",
    8: "Business and Finance" or "Negocios y finanzas" or "Affaires et finances" or "Wirtschaft und Finanzen" or "Affari e finanza",
    9: "Social Media and Internet" or "Redes sociales e internet" or "Médias sociaux et internet" or "Soziale Medien und Internet" or "Social media e internet",
    10: "Food and Dining" or "Comida y restaurantes" or "Nourriture et restauration" or "Essen und Gastronomie" or "Cibo e ristorazione",
    11: "Music" or "Música" or "Musique" or "Musik" or "Musica",
    12: "Books and Literature" or "Libros y literatura" or "Livres et littérature" or "Bücher und Literatur" or "Libri e letteratura",
    13: "Movies" or "Películas" or "Films" or "Filme" or "Film",
    14: "Art and Culture" or "Arte y cultura" or "Art et culture" or "Kunst und Kultur" or "Arte e cultura",
    15: "Science and Nature" or "Ciencia y naturaleza" or "Sciences et nature" or "Wissenschaft und Natur" or "Scienza e natura",
    16: "Education" or "Educación" or "Éducation" or "Bildung" or "Educazione",
    17: "Gaming" or "Videojuegos" or "Jeux vidéo" or "Spiele" or "Giochi",
    18: "Motivation and Inspiration" or "Motivación e inspiración" or "Motivation et inspiration" or "Motivation und Inspiration" or "Motivazione e ispirazione",
    19: "Humor and Memes" or "Humor y memes" or "Humour et mèmes" or "Humor und Memes" or "Umorismo e meme",
    20: "Environment and Sustainability" or "Medio ambiente y sostenibilidad" or "Environnement et durabilité" or "Umwelt und Nachhaltigkeit" or "Ambiente e sostenibilità",
    21: "History and Heritage" or "Historia y patrimonio" or "Histoire et patrimoine" or "Geschichte und Erbe" or "Storia e patrimonio",
    22: "Technology and Innovation" or "Tecnología e innovación" or "Technologie et innovation" or "Technologie und Innovation" or "Tecnologia e innovazione",
    23: "Home and Interior Design" or "Hogar y diseño de interiores" or "Maison et design d'intérieur" or "Zuhause und Innenarchitektur" or "Casa e design d'interni",
    24: "Parenting and Family" or "Paternidad y familia" or "Parentalité et famille" or "Elternschaft und Familie" or "Genitorialità e famiglia",
    25: "Relationships and Dating" or "Relaciones y citas" or "Relations et rencontres" or "Beziehungen und Dating" or "Relazioni e appuntamenti",
    26: "Spirituality and Religion" or "Espiritualidad y religión" or "Spiritualité et religion" or "Spiritualität und Religion" or "Spiritualità e religione",
    27: "Pets and Animals" or "Mascotas y animales" or "Animaux de compagnie et animaux" or "Haustiere und Tiere" or "Animali domestici e animali",
    28: "DIY and Crafts" or "Hazlo tú mismo y manualidades" or "Bricolage et artisanat" or "Selbermachen und Handwerk" or "Fai da te e artigianato",
    29: "Photography" or "Fotografía" or "Photographie" or "Fotografie" or "Fotografia"
    }

# %%
# Inferencia de tópicos para nuevos documentos
new_tweets = [
    "Just watched an amazing movie, highly recommended!",
    "Sunny weather today, perfect for outdoor activities.",
    "Feeling tired after a long day at work.",
    "Attending a live theater performance, appreciating the arts.",
    "Indulging in a sweet treat, enjoying a decadent dessert.",
    "Trying a new hobby, discovering new passions."
]

# %%
preprocessed_new_tweets = [tweet.lower().split() for tweet in result]
new_corpus = [dictionary.doc2bow(tweet) for tweet in preprocessed_new_tweets]

# %%
# Inferencia de tópicos para todos los documentos
all_topics = []
for i, tweet in enumerate(result):
    topics = lda_model.get_document_topics(corpus[i])
    if topics:
        dominant_topic = max(topics, key=lambda x: x[1])
        all_topics.append(dominant_topic[0])

# %%
# Tópico general basado en el promedio
if all_topics:
    topic_counter = Counter(all_topics)
    most_common_topic = topic_counter.most_common(1)[0][0]
    general_topic = topic_names[most_common_topic]
    print(f"Tópico general: {general_topic}")
else:
    print("No se encontraron tópicos en los tweets.")
# Out:
# Tópico general: News and Current Events

# %% [markdown]
# # Codigo arreglado

# %%
import pandas as pd
from gensim.corpora import Dictionary
from gensim.models import LdaModel
from collections import Counter
from gensim.parsing.preprocessing import preprocess_string, strip_punctuation, strip_numeric, remove_stopwords

# Cargar datos desde CSV
df = pd.read_csv('csv\carlos_hernandez_tweets.csv')

# Extraer la columna 'tweet' y convertirla en una lista
tweets = df['tweet'].tolist()

# Preprocesamiento de los tweets: convertir a minúsculas y eliminar puntuación. Mantenemos los números y las palabras comunes
preprocessed_tweets = [preprocess_string(tweet, [lambda x: x.lower(), strip_punctuation]) for tweet in tweets]

# Creación del diccionario de palabras
dictionary = Dictionary(preprocessed_tweets)
dictionary.filter_extremes(no_below=10, no_above=0.7)  # Filtrar palabras muy raras o muy frecuentes

# Creación del corpus de documentos
corpus = [dictionary.doc2bow(tweet) for tweet in preprocessed_tweets]

# Entrenamiento del modelo LDA
num_topics = 10  # Reducir el número de tópicos
lda_model = LdaModel(corpus, num_topics=num_topics, id2word=dictionary, passes=500, random_state=42)  # Aumentar las pasadas y establecer una semilla aleatoria

# Definir nombres de los tópicos
# Asignación de nombres a los tópicos
topic_names = {
    0: "News and Current Events" or "Noticias y eventos actuales" or "Actualités et événements en cours" or "Nachrichten und aktuelle Ereignisse" or "Notizie e eventi attuali",
    1: "Sports" or "Deportes" or "Sports" or "Sport" or "Sport",
    2: "Entertainment" or "Entretenimiento" or "Divertissement" or "Unterhaltung" or "Intrattenimento",
    3: "Politics" or "Política" or "Politique" or "Politik" or "Politica",
    4: "Technology" or "Tecnología" or "Technologie" or "Technologie" or "Tecnologia",
    5: "Fashion and Beauty" or "Moda y belleza" or "Mode et beauté" or "Mode und Schönheit" or "Moda e bellezza",
    6: "Travel" or "Viajes" or "Voyage" or "Reisen" or "Viaggi",
    7: "Health and Fitness" or "Salud y bienestar" or "Santé et forme physique" or "Gesundheit und Fitness" or "Salute e fitness",
    8: "Business and Finance" or "Negocios y finanzas" or "Affaires et finances" or "Wirtschaft und Finanzen" or "Affari e finanza",
    9: "Social Media and Internet" or "Redes sociales e internet" or "Médias sociaux et internet" or "Soziale Medien und Internet" or "Social media e internet",
    10: "Food and Dining" or "Comida y restaurantes" or "Nourriture et restauration" or "Essen und Gastronomie" or "Cibo e ristorazione",
    11: "Music" or "Música" or "Musique" or "Musik" or "Musica",
    12: "Books and Literature" or "Libros y literatura" or "Livres et littérature" or "Bücher und Literatur" or "Libri e letteratura",
    13: "Movies" or "Películas" or "Films" or "Filme" or "Film",
    14: "Art and Culture" or "Arte y cultura" or "Art et culture" or "Kunst und Kultur" or "Arte e cultura",
    15: "Science and Nature" or "Ciencia y naturaleza" or "Sciences et nature" or "Wissenschaft und Natur" or "Scienza e natura",
    16: "Education" or "Educación" or "Éducation" or "Bildung" or "Educazione",
    17: "Gaming" or "Videojuegos" or "Jeux vidéo" or "Spiele" or "Giochi",
    18: "Motivation and Inspiration" or "Motivación e inspiración" or "Motivation et inspiration" or "Motivation und Inspiration" or "Motivazione e ispirazione",
    19: "Humor and Memes" or "Humor y memes" or "Humour et mèmes" or "Humor und Memes" or "Umorismo e meme",
    20: "Environment and Sustainability" or "Medio ambiente y sostenibilidad" or "Environnement et durabilité" or "Umwelt und Nachhaltigkeit" or "Ambiente e sostenibilità",
    21: "History and Heritage" or "Historia y patrimonio" or "Histoire et patrimoine" or "Geschichte und Erbe" or "Storia e patrimonio",
    22: "Technology and Innovation" or "Tecnología e innovación" or "Technologie et innovation" or "Technologie und Innovation" or "Tecnologia e innovazione",
    23: "Home and Interior Design" or "Hogar y diseño de interiores" or "Maison et design d'intérieur" or "Zuhause und Innenarchitektur" or "Casa e design d'interni",
    24: "Parenting and Family" or "Paternidad y familia" or "Parentalité et famille" or "Elternschaft und Familie" or "Genitorialità e famiglia",
    25: "Relationships and Dating" or "Relaciones y citas" or "Relations et rencontres" or "Beziehungen und Dating" or "Relazioni e appuntamenti",
    26: "Spirituality and Religion" or "Espiritualidad y religión" or "Spiritualité et religion" or "Spiritualität und Religion" or "Spiritualità e religione",
    27: "Pets and Animals" or "Mascotas y animales" or "Animaux de compagnie et animaux" or "Haustiere und Tiere" or "Animali domestici e animali",
    28: "DIY and Crafts" or "Hazlo tú mismo y manualidades" or "Bricolage et artisanat" or "Selbermachen und Handwerk" or "Fai da te e artigianato",
    29: "Photography" or "Fotografía" or "Photographie" or "Fotografie" or "Fotografia"
    }

# Inferencia de tópicos para todos los documentos
all_topics = []
for i, tweet in enumerate(preprocessed_tweets):
    topics = lda_model.get_document_topics(corpus[i])
    if topics:
        dominant_topic = max(topics, key=lambda x: x[1])
        all_topics.append(dominant_topic[0])

# Tópico general basado en el promedio
if all_topics:
    topic_counter = Counter(all_topics)
    most_common_topic = topic_counter.most_common(1)[0][0]
    general_topic = topic_names[most_common_topic]
    print(f"Tópico general: {general_topic}")
else:
    print("No se encontraron tópicos en los tweets.")
# Out:
# Tópico general: Social Media and Internet

# %% [markdown]
# # __Principales temas discutidos por la cuenta  (USAR)__

# %%
import pandas as pd
from gensim.corpora import Dictionary
from gensim.models import LdaModel
from collections import Counter
from gensim.parsing.preprocessing import preprocess_string, strip_punctuation, strip_numeric, remove_stopwords

# Cargar datos desde CSV
df = pd.read_csv('csv\Ari_tweets.csv')

# Extraer la columna 'tweet' y convertirla en una lista
tweets = df['tweet'].tolist()

# Preprocesamiento de los tweets: convertir a minúsculas y eliminar puntuación. Mantenemos los números y las palabras comunes
preprocessed_tweets = [preprocess_string(tweet, [lambda x: x.lower(), strip_punctuation]) for tweet in tweets]

# Creación del diccionario de palabras
dictionary = Dictionary(preprocessed_tweets)
dictionary.filter_extremes(no_below=10, no_above=0.7)  # Filtrar palabras muy raras o muy frecuentes

# Creación del corpus de documentos
corpus = [dictionary.doc2bow(tweet) for tweet in preprocessed_tweets]

# Entrenamiento del modelo LDA
num_topics = 10  # Reducir el número de tópicos
lda_model = LdaModel(corpus, num_topics=num_topics, id2word=dictionary, passes=500, random_state=42)


# Definir nombres de los tópicos en diferentes idiomas
topic_names_es = {
    0: "Noticias y eventos actuales",
    1: "Deportes",
    2: "Entretenimiento",
    3: "Política",
    4: "Tecnología",
    5: "Moda y belleza",
    6: "Viajes",
    7: "Salud y bienestar",
    8: "Negocios y finanzas",
    9: "Redes sociales e internet",
    10: "Comida y restaurantes",
    11: "Música",
    12: "Libros y literatura",
    13: "Películas",
    14: "Arte y cultura",
    15: "Ciencia y naturaleza",
    16: "Educación",
    17: "Videojuegos",
    18: "Motivación e inspiración",
    19: "Humor y memes",
    20: "Medio ambiente y sostenibilidad",
    21: "Historia y patrimonio",
    22: "Tecnología e innovación",
    23: "Hogar y diseño de interiores",
    24: "Paternidad y familia",
    25: "Relaciones y citas",
    26: "Espiritualidad y religión",
    27: "Mascotas y animales",
    28: "Hazlo tú mismo y manualidades",
    29: "Fotografía"
}

topic_names_en = {
    0: "News and Current Events",
    1: "Sports",
    2: "Entertainment",
    3: "Politics",
    4: "Technology",
    5: "Fashion and Beauty",
    6: "Travel",
    7: "Health and Fitness",
    8: "Business and Finance",
    9: "Social Media and Internet",
    10: "Food and Dining",
    11: "Music",
    12: "Books and Literature",
    13: "Movies",
    14: "Art and Culture",
    15: "Science and Nature",
    16: "Education",
    17: "Gaming",
    18: "Motivation and Inspiration",
    19: "Humor and Memes",
    20: "Environment and Sustainability",
    21: "History and Heritage",
    22: "Technology and Innovation",
    23: "Home and Interior Design",
    24: "Parenting and Family",
    25: "Relationships and Dating",
    26: "Spirituality and Religion",
    27: "Pets and Animals",
    28: "DIY and Crafts",
    29: "Photography"
}

topic_names_fr = {
    0: "Actualités et événements en cours",
    1: "Sports",
    2: "Divertissement",
    3: "Politique",
    4: "Technologie",
    5: "Mode et beauté",
    6: "Voyage",
    7: "Santé et forme physique",
    8: "Affaires et finances",
    9: "Médias sociaux et internet",
    10: "Nourriture et restauration",
    11: "Musique",
    12: "Livres et littérature",
    13: "Films",
    14: "Art et culture",
    15: "Sciences et nature",
    16: "Éducation",
    17: "Jeux vidéo",
    18: "Motivation et inspiration",
    19: "Humour et mèmes",
    20: "Environnement et durabilité",
    21: "Histoire et patrimoine",
    22: "Technologie et innovation",
    23: "Maison et design d'intérieur",
    24: "Parentalité et famille",
    25: "Relations et rencontres",
    26: "Spiritualité et religion",
    27: "Animaux de compagnie et animaux",
    28: "Bricolage et artisanat",
    29: "Photographie"
}

topic_names_de = {
    0: "Nachrichten und aktuelle Ereignisse",
    1: "Sport",
    2: "Unterhaltung",
    3: "Politik",
    4: "Technologie",
    5: "Mode und Schönheit",
    6: "Reisen",
    7: "Gesundheit und Fitness",
    8: "Wirtschaft und Finanzen",
    9: "Soziale Medien und Internet",
    10: "Essen und Gastronomie",
    11: "Musik",
    12: "Bücher und Literatur",
    13: "Filme",
    14: "Kunst und Kultur",
    15: "Wissenschaft und Natur",
    16: "Bildung",
    17: "Spiele",
    18: "Motivation und Inspiration",
    19: "Humor und Memes",
    20: "Umwelt und Nachhaltigkeit",
    21: "Geschichte und Erbe",
    22: "Technologie und Innovation",
    23: "Zuhause und Innenarchitektur",
    24: "Elternschaft und Familie",
    25: "Beziehungen und Dating",
    26: "Spiritualität und Religion",
    27: "Haustiere und Tiere",
    28: "Selbermachen und Handwerk",
    29: "Fotografie"

}

topic_names_it = {
    0: "Notizie e eventi attuali",
    1: "Sport",
    2: "Intrattenimento",
    3: "Politica",
    4: "Tecnologia",
    5: "Moda e bellezza",
    6: "Viaggi",
    7: "Salute e fitness",
    8: "Affari e finanza",
    9: "Social media e internet",
    10: "Cibo e ristorazione",
    11: "Musica",
    12: "Libri e letteratura",
    13: "Film",
    14: "Arte e cultura",
    15: "Scienza e natura",
    16: "Educazione",
    17: "Giochi",
    18: "Motivazione e ispirazione",
    19: "Umorismo e meme",
    20: "Ambiente e sostenibilità",
    21: "Storia e patrimonio",
    22: "Tecnologia e innovazione",
    23: "Casa e design d'interni",
    24: "Genitorialità e famiglia",
    25: "Relazioni e appuntamenti",
    26: "Spiritualità e religione",
    27: "Animali domestici e animali",
    28: "Fai da te e artigianato",
    29: "Fotografia"
}

# ... agregar más diccionarios de tópicos para otros idiomas

# Seleccionar el diccionario de tópicos apropiado para el idioma de entrada
language = "es"  # reemplazar con la detección del idioma
if language == "es":
    topic_names = topic_names_es
elif language == "en":
    topic_names = topic_names_en
elif language == "fr":
    topic_names = topic_names_fr
elif language == "de":
    topic_names = topic_names_de
elif language == "it":
    topic_names = topic_names_it

# ... agregar más condiciones para otros idiomas

# Inferencia de tópicos para todos los documentos
all_topics = []
for i, tweet in enumerate(preprocessed_tweets):
    topics = lda_model.get_document_topics(corpus[i])
    if topics:
        dominant_topic = max(topics, key=lambda x: x[1])
        all_topics.append(dominant_topic[0])

# Tópico general basado en el promedio
if all_topics:
    topic_counter = Counter(all_topics)
    most_common_topics = topic_counter.most_common(3)  # obtener los 3 tópicos más comunes
    general_topics = [topic_names[topic[0]] for topic in most_common_topics if topic[1] > 1]  # sólo considerar tópicos con más de 1 ocurrencia
    print(f"Tópicos generales: {', '.join(general_topics)}")
else:
    print("No se encontraron tópicos en los tweets.")
# Out:
# Tópicos generales: Deportes, Redes sociales e internet, Entretenimiento

# %% [markdown]
# # EL MEJOR

# %%
import pandas as pd
from gensim.corpora import Dictionary
from gensim.models import LdaModel
from collections import Counter
from gensim.parsing.preprocessing import preprocess_string, strip_punctuation, strip_numeric, remove_stopwords
from langdetect import detect
from gensim.models import CoherenceModel

# Cargar datos desde CSV
df = pd.read_csv('csv\AlfaRomeo_tweets.csv')


# Extraer la columna 'tweet' y convertirla en una lista
tweets = df['tweet'].tolist()

# Preprocesamiento de los tweets: convertir a minúsculas y eliminar puntuación. Mantenemos los números y las palabras comunes
preprocessed_tweets = [preprocess_string(tweet, [lambda x: x.lower(), strip_punctuation]) for tweet in tweets]

# Creación del diccionario de palabras
dictionary = Dictionary(preprocessed_tweets)
dictionary.filter_extremes(no_below=10, no_above=0.7)  # Filtrar palabras muy raras o muy frecuentes

# Creación del corpus de documentos
corpus = [dictionary.doc2bow(tweet) for tweet in preprocessed_tweets]

# Entrenamiento del modelo LDA
num_topics = 29  # Reducir el número de tópicos
lda_model = LdaModel(corpus, num_topics=num_topics, id2word=dictionary, passes=500, random_state=42)

# Intentar detectar el idioma del primer tweet
try:
    language = detect(tweets[0])[:2]  # detect() devuelve un código de idioma ISO 639-1 (como "en" para inglés)
except:
    language = "en"  # si la detección falla, por defecto a inglés

# Definir nombres de los tópicos en diferentes idiomas
topic_names_es = {
    0: "Noticias y eventos actuales",
    1: "Deportes",
    2: "Entretenimiento",
    3: "Política",
    4: "Tecnología",
    5: "Moda y belleza",
    6: "Viajes",
    7: "Salud y bienestar",
    8: "Negocios y finanzas",
    9: "Redes sociales e internet",
    10: "Comida y restaurantes",
    11: "Música",
    12: "Libros y literatura",
    13: "Películas",
    14: "Arte y cultura",
    15: "Ciencia y naturaleza",
    16: "Educación",
    17: "Videojuegos",
    18: "Motivación e inspiración",
    19: "Humor y memes",
    20: "Medio ambiente y sostenibilidad",
    21: "Historia y patrimonio",
    22: "Tecnología e innovación",
    23: "Hogar y diseño de interiores",
    24: "Paternidad y familia",
    25: "Relaciones y citas",
    26: "Espiritualidad y religión",
    27: "Mascotas y animales",
    28: "Hazlo tú mismo y manualidades",
    29: "Fotografía"
}

topic_names_en = {
    0: "News and Current Events",
    1: "Sports",
    2: "Entertainment",
    3: "Politics",
    4: "Technology",
    5: "Fashion and Beauty",
    6: "Travel",
    7: "Health and Fitness",
    8: "Business and Finance",
    9: "Social Media and Internet",
    10: "Food and Dining",
    11: "Music",
    12: "Books and Literature",
    13: "Movies",
    14: "Art and Culture",
    15: "Science and Nature",
    16: "Education",
    17: "Gaming",
    18: "Motivation and Inspiration",
    19: "Humor and Memes",
    20: "Environment and Sustainability",
    21: "History and Heritage",
    22: "Technology and Innovation",
    23: "Home and Interior Design",
    24: "Parenting and Family",
    25: "Relationships and Dating",
    26: "Spirituality and Religion",
    27: "Pets and Animals",
    28: "DIY and Crafts",
    29: "Photography"
}

topic_names_fr = {
0: "Actualités et événements en cours",
1: "Sports",
2: "Divertissement",
3: "Politique",
4: "Technologie",
5: "Mode et beauté",
6: "Voyage",
7: "Santé et forme physique",
8: "Affaires et finances",
9: "Médias sociaux et internet",
10: "Nourriture et restauration",
11: "Musique",
12: "Livres et littérature",
13: "Films",
14: "Art et culture",
15: "Sciences et nature",
16: "Éducation",
17: "Jeux vidéo",
18: "Motivation et inspiration",
19: "Humour et mèmes",
20: "Environnement et durabilité",
21: "Histoire et patrimoine",
22: "Technologie et innovation",
23: "Maison et design d'intérieur",
24: "Parentalité et famille",
25: "Relations et rencontres",
26: "Spiritualité et religion",
27: "Animaux de compagnie et animaux",
28: "Bricolage et artisanat",
29: "Photographie"
}

topic_names_de = {
    0: "Nachrichten und aktuelle Ereignisse",
    1: "Sport",
    2: "Unterhaltung",
    3: "Politik",
    4: "Technologie",
    5: "Mode und Schönheit",
    6: "Reisen",
    7: "Gesundheit und Fitness",
    8: "Wirtschaft und Finanzen",
    9: "Soziale Medien und Internet",
    10: "Essen und Gastronomie",
    11: "Musik",
    12: "Bücher und Literatur",
    13: "Filme",
    14: "Kunst und Kultur",
    15: "Wissenschaft und Natur",
    16: "Bildung",
    17: "Spiele",
    18: "Motivation und Inspiration",
    19: "Humor und Memes",
    20: "Umwelt und Nachhaltigkeit",
    21: "Geschichte und Erbe",
    22: "Technologie und Innovation",
    23: "Zuhause und Innenarchitektur",
    24: "Elternschaft und Familie",
    25: "Beziehungen und Dating",
    26: "Spiritualität und Religion",
    27: "Haustiere und Tiere",
    28: "Selbermachen und Handwerk",
    29: "Fotografie"
}

topic_names_it = {
    0: "Notizie e eventi attuali",
    1: "Sport",
    2: "Intrattenimento",
    3: "Politica",
    4: "Tecnologia",
    5: "Moda e bellezza",
    6: "Viaggi",
    7: "Salute e fitness",
    8: "Affari e finanza",
    9: "Social media e internet",
    10: "Cibo e ristorazione",
    11: "Musica",
    12: "Libri e letteratura",
    13: "Film",
    14: "Arte e cultura",
    15: "Scienza e natura",
    16: "Educazione",
    17: "Giochi",
    18: "Motivazione e ispirazione",
    19: "Umorismo e meme",
    20: "Ambiente e sostenibilità",
    21: "Storia e patrimonio",
    22: "Tecnologia e innovazione",
    23: "Casa e design d'interni",
    24: "Genitorialità e famiglia",
    25: "Relazioni e appuntamenti",
    26: "Spiritualità e religione",
    27: "Animali domestici e animali",
    28: "Fai da te e artigianato",
    29: "Fotografia"
}

# Seleccionar el diccionario de tópicos apropiado para el idioma de entrada
if language == "es":
    topic_names = topic_names_es
elif language == "en":
    topic_names = topic_names_en
elif language == "fr":
    topic_names = topic_names_fr
elif language == "de":
    topic_names = topic_names_de
elif language == "it":
    topic_names = topic_names_it

# Inferencia de tópicos para todos los documentos
all_topics = []
for i, tweet in enumerate(preprocessed_tweets):
    topics = lda_model.get_document_topics(corpus[i])
    if topics:
        dominant_topic = max(topics, key=lambda x: x[1])
        all_topics.append(dominant_topic[0])

# Tópico general basado en el promedio
if all_topics:
    topic_counter = Counter(all_topics)
    most_common_topics = topic_counter.most_common(3)  # obtener los 3 tópicos más comunes
    general_topics = [topic_names[topic[0]] for topic in most_common_topics if topic[1] > 1]  # sólo considerar tópicos con más de 1 ocurrencia
    print(f"Tópics: {', '.join(general_topics)}")
else:
    print("No se encontraron tópicos en los tweets.")
# Out:
# Tópics: Parentalité et famille, Technologie, Films

# %%
print(general_topics)
# Out:
# ['Redes sociales e internet', 'Hogar y diseño de interiores', 'Películas']

# %% [markdown]
# # TESTEO

# %%
import pandas as pd
from gensim.corpora import Dictionary
from gensim.models import LdaModel
from collections import Counter
from gensim.parsing.preprocessing import preprocess_string, strip_punctuation, strip_numeric, STOPWORDS
from langdetect import detect
from gensim.models import CoherenceModel
from nltk.stem import SnowballStemmer

# Cargar datos desde CSV
df = pd.read_csv('csv\AlfaRomeo_tweets.csv')

# Extraer la columna 'tweet' y convertirla en una lista
tweets = df['tweet'].tolist()

# Identificar el idioma de cada tweet y almacenar en una lista
languages = [detect(tweet) for tweet in tweets]

# Generar un stemmer para cada idioma
stemmers = {
    'en': SnowballStemmer('english'),
    'es': SnowballStemmer('spanish'),
    'de': SnowballStemmer('german'),
    'fr': SnowballStemmer('french'),
    'it': SnowballStemmer('italian'),
    # añadir más stemmers para otros idiomas si es necesario
}

# Preprocesamiento de los tweets: convertir a minúsculas y eliminar puntuación. Eliminar los números y las palabras comunes
preprocessed_tweets = []
for i, tweet in enumerate(tweets):
    if languages[i] in stemmers:
        stemmer = stemmers[languages[i]]
        tweet = preprocess_string(tweet, [lambda x: x.lower(), strip_punctuation, strip_numeric])
        tweet = [stemmer.stem(word) for word in tweet if word not in STOPWORDS]
        preprocessed_tweets.append(tweet)

# Creación del diccionario de palabras
dictionary = Dictionary(preprocessed_tweets)
dictionary.filter_extremes(no_below=10, no_above=0.7)  # Filtrar palabras muy raras o muy frecuentes

# Creación del corpus de documentos
corpus = [dictionary.doc2bow(tweet) for tweet in preprocessed_tweets]

# Entrenamiento del modelo LDA
num_topics = 20  # Reducir el número de tópicos
lda_model = LdaModel(corpus, num_topics=num_topics, id2word=dictionary, passes=500, random_state=42)

# Definir nombres de los tópicos en diferentes idiomas
topic_names_es = {
    0: "Deportes",
    1: "Entretenimiento",
    2: "Política",
    3: "Tecnología",
    4: "Moda y belleza",
    5: "Viajes",
    6: "Negocios y finanzas",
    7: "Redes sociales e internet",
    8: "Comida y restaurantes",
    9: "Música",
    10: "Arte y cultura",
    11: "Ciencia y naturaleza",
    12: "Educación",
    13: "Videojuegos",
    14: "Humor y memes",
    15: "Tecnología e innovación",
    16: "Hogar y diseño de interiores",
    17: "Relaciones y citas",
    18: "Espiritualidad y religión",
    19: "Mascotas y animales",
}

topic_names_en = {
    0: "Sports",
    1: "Entertainment",
    2: "Politics",
    3: "Technology",
    4: "Fashion and Beauty",
    5: "Travel",
    6: "Business and Finance",
    7: "Social Media and Internet",
    8: "Food and Restaurants",
    9: "Music",
    10: "Art and Culture",
    11: "Science and Nature",
    12: "Education",
    13: "Video Games",
    14: "Humor and Memes",
    15: "Technology and Innovation",
    16: "Home and Interior Design",
    17: "Relationships and Dating",
    18: "Spirituality and Religion",
    19: "Pets and Animals",

}

topic_names_fr = {
    0: "Sports",
    1: "Divertissement",
    2: "Politique",
    3: "Technologie",
    4: "Mode et beauté",
    5: "Voyages",
    6: "Affaires et finances",
    7: "Réseaux sociaux et internet",
    8: "Alimentation et restaurants",
    9: "Musique",
    10: "Art et culture",
    11: "Science et nature",
    12: "Éducation",
    13: "Jeux vidéo",
    14: "Humour et memes",
    15: "Technologie et innovation",
    16: "Maison et design d'intérieur",
    17: "Relations et rencontres",
    18: "Spiritualité et religion",
    19: "Animaux de compagnie et animaux",
}

topic_names_de = {
    0: "Sport",
    1: "Unterhaltung",
    2: "Politik",
    3: "Technologie",
    4: "Mode und Schönheit",
    5: "Reisen",
    6: "Geschäft und Finanzen",
    7: "Soziale Medien und Internet",
    8: "Essen und Restaurants",
    9: "Musik",
    10: "Kunst und Kultur",
    11: "Wissenschaft und Natur",
    12: "Bildung",
    13: "Videospiele",
    14: "Humor und Memes",
    15: "Technologie und Innovation",
    16: "Zuhause und Innenarchitektur",
    17: "Beziehungen und Dating",
    18: "Spiritualität und Religion",
    19: "Haustiere und Tiere",
}

topic_names_it = {
    0: "Sport",
    1: "Intrattenimento",
    2: "Politica",
    3: "Tecnologia",
    4: "Moda e bellezza",
    5: "Viaggi",
    6: "Affari e finanze",
    7: "Social media e internet",
    8: "Cibo e ristoranti",
    9: "Musica",
    10: "Arte e cultura",
    11: "Scienza e natura",
    12: "Educazione",
    13: "Videogiochi",
    14: "Umorismo e meme",
    15: "Tecnologia e innovazione",
    16: "Casa e design d'interni",
    17: "Relazioni e appuntamenti",
    18: "Spiritualità e religione",
    19: "Animali domestici e animali",
    }

# Inferencia de tópicos para todos los documentos
all_topics = []
for i, tweet in enumerate(preprocessed_tweets):
    topics = lda_model.get_document_topics(corpus[i])
    if topics:
        dominant_topic = max(topics, key=lambda x: x[1])
        all_topics.append(dominant_topic[0])

# Tópico general basado en el promedio
if all_topics:
    topic_counter = Counter(all_topics)
    most_common_topics = topic_counter.most_common(3)  # obtener los 3 tópicos más comunes
    
    # Determinar los nombres de los tópicos en función del idioma de cada tweet
    general_topics = []
    for topic in most_common_topics:
        if topic[1] > 1:  # sólo considerar tópicos con más de 1 ocurrencia
            if languages[i] == "es": # Aquí se realiza el cambio
                general_topics.append(topic_names_es[topic[0]])
            elif languages[i] == "en": # Aquí se realiza el cambio
                general_topics.append(topic_names_en[topic[0]])
            elif languages[i] == "fr": # Aquí se realiza el cambio
                general_topics.append(topic_names_fr[topic[0]])
            elif languages[i] == "de": # Aquí se realiza el cambio
                general_topics.append(topic_names_de[topic[0]])
            elif languages[i] == "it": # Aquí se realiza el cambio
                general_topics.append(topic_names_it[topic[0]])
            # ... agregar más condiciones para otros idiomas

    print(f"Tópicos: {', '.join(general_topics)}")
else:
    print("No se encontraron tópicos en los tweets.")
# Out:
# Tópicos: Technologie, Alimentation et restaurants, Musique

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re

# Descargar los datos necesarios de NLTK
nltk.download('wordnet')
nltk.download('stopwords')

# Inicializar el lematizador y obtener las stop words del inglés
lemmatizer = WordNetLemmatizer()
stop_words = stopwords.words('english')

def preprocess(text):
    # Convertir el texto a minúsculas
    text = text.lower()
    # Eliminar caracteres especiales
    text = re.sub(r'\W', ' ', text)
    text = re.sub(r'\s+', ' ', text)
    # Eliminar stop words y lematizar
    text = [lemmatizer.lemmatize(word) for word in text.split() if word not in stop_words]
    return text

# Aplicar el preprocesamiento al texto
data['text'] = data['text'].apply(preprocess)

# Continuar con el resto del código aquí...
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\matia\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\matia\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 25
#      22     return text
#      24 # Aplicar el preprocesamiento al texto
# ---> 25 data['text'] = data['text'].apply(preprocess)
#      27 # Continuar con el resto del código aquí...
#
# NameError: name 'data' is not defined
